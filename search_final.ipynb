# %%
import numpy as np
import pandas as pd

# %%
final = pd.read_csv('raw_data/final.csv')
# Out:
# /usr/local/Cellar/ipython@5/5.5.0_4/libexec/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (56,58) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
def find_course(year, term, department1, course_number1):
    df = final[(final['year'] == year) & 
               (final['term'] == term) &
               (final['course_number1'] == course_number1) &
               (final['department1'] == department1)]
    return df

# %%
final[(final.year==2017) & (final.term=='fall')].shape
# Out:
# (1249, 66)

# %%
find_course(2017, 'spring', 'MATH', '101')
# Out:
#        Unnamed: 0 web-scraper-order  \
# 25425         734  1522924305-38388
#
#                                    web-scraper-start-url  \
# 25425  https://course-evaluation-reports.fas.harvard....
#
#                                      course comments  year    term  \
# 25425  MATH 101:  Sets, Groups and Topology       []  2017  spring
#
#                     course_title course_number1 department1  \
# 25425  Sets, Groups and Topology            101        MATH
#
#                     ...                Course_Goals_Distribution  \
# 25425               ...                                      NaN
#
#       Course_Recommend_Distribution Course_Money_Distribution  \
# 25425              [0, 1, 3, 7, 10]          [20, 1, 0, 0, 0]
#
#       Instructor_Return_Distribution Instructor_Feedback_Distribution  \
# 25425               [0, 0, 0, 4, 17]                 [0, 0, 1, 2, 18]
#
#        Instructor_Participation_Distribution  \
# 25425                       [0, 0, 0, 2, 19]
#
# ...

# %%
final
# Out:
#    Unnamed: 0 web-scraper-order  \
# 0           0  1522891683-18234
# 1           1  1522891674-18223
# 2           2  1522891670-18217
# 3           3  1522891657-18200
# 4           4  1522891495-18013
#
#                                web-scraper-start-url  \
# 0  https://course-evaluation-reports.fas.harvard....
# 1  https://course-evaluation-reports.fas.harvard....
# 2  https://course-evaluation-reports.fas.harvard....
# 3  https://course-evaluation-reports.fas.harvard....
# 4  https://course-evaluation-reports.fas.harvard....
#
#                                               course comments  year  term  \
# 0  AFRAMER 112:  Black Humor: Performance Art and...       []  2006  fall
# 1  AFRAMER 113:  Fictions of Race, Facts of Racis...       []  2006  fall
# 2  AFRAMER 116:  Autobiography and Literary Imagi...       []  2006  fall
# 3        AFRAMER 175:  Introduction to African Music       []  2006  fall
# ...
